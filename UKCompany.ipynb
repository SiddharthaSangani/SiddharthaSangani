# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddharthaSangani/SiddharthaSangani/blob/main/UKCompany.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
import os

# %% [markdown]
# Uploading the file

# %%
zip_path = '/content/drive/MyDrive/archive.zip'
extract_path = '/content/data'

# %%
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
os.listdir(extract_path)
# Out:
# ['corporate_uk']

# %%
import pandas as pd

# %%
import os

# Check extracted files
extracted_files = os.listdir(extract_path)
print("Extracted Files:", extracted_files)
# Out:
# Extracted Files: ['corporate_uk']

# %%
import os

# List all files in the Colab session
for root, dirs, files in os.walk("/content"):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content/.config/default_configs.db
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/active_config
# /content/.config/gce
# /content/.config/.last_survey_prompt.yaml
# /content/.config/.last_update_check.json
# /content/.config/config_sentinel
# /content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# /content/.config/logs/2025.04.21/18.42.22.411154.log
# /content/.config/logs/2025.04.21/18.42.31.744939.log
# /content/.config/logs/2025.04.21/18.42.12.824329.log
# /content/.config/logs/2025.04.21/18.42.21.235934.log
# /content/.config/logs/2025.04.21/18.42.31.045496.log
# /content/.config/logs/2025.04.21/18.41.51.884422.log
# /content/.config/configurations/config_default
# /content/data/corporate_uk/companies.csv
# /content/data/corporate_uk/filings.csv
# /content/data/corporate_uk/companies_sic_codes.csv
# /content/data/corporate_uk/officers_and_owners.csv
# /content/drive/MyDrive/Getting started.pdf
# /content/drive/MyDrive/DS Sem 2 imp.pdf
# /content/drive/MyDrive/certificate.pdf
# /content/drive/MyDrive/ntTvo6ru6Tq3A2JPq_BCG_A4iMTRe4hN9yZzyyi_completion_certificate.pdf
# /content/drive/MyDrive/Sangani_Siddhartha_Hired_Certificate.pdf
# /content/drive/MyDrive/TSF GRIP Certificate Sangani Siddhartha.jpg
# /content/drive/MyDrive/Suven consultants internship.pdf
# /content/drive/MyDrive/Sangani college dunia.png
# /content/drive/MyDrive/SANGANI10.pdf
# /content/drive/MyDrive/IMG-20191006-WA0037.jpg
# /content/drive/MyDrive/grip web development.pdf
# /content/drive/MyDrive/Sangani.png
# /content/drive/MyDrive/HRM Certificates 18-03-2021.pdf
# /content/drive/MyDrive/Human Resources (HR)_internship_certificate.pdf
# /content/drive/MyDrive/IMG-20210508-WA0004.jpg
# /content/drive/MyDrive/IMG-20210508-WA0003.jpg
# /content/drive/MyDrive/Human Resources (HR)_internship_certificate-2.pdf
# /content/drive/MyDrive/27-MS Certificates - January Internship 2021 402.jpeg
# /content/drive/MyDrive/27-SMM Certificates - January Internship 2021 402.jpeg
# /content/drive/MyDrive/27-HRM Certificate - January Internship 2021 27.jpeg
# /content/drive/MyDrive/27-HREB Certificate - January Internship 2021 402.jpeg
# /content/drive/MyDrive/27-BD Certificates - January Internship 2021 402.jpeg
# /content/drive/MyDrive/Sangani Siddhartha SC1181.jpg
# /content/drive/MyDrive/SC1181LOR.pdf
# /content/drive/MyDrive/IBMCE CEDTH1IN Certificate _ SmartBridge.pdf
# /content/drive/MyDrive/IBMCE CEDEV1IN Certificate _ SmartBridge.pdf
# /content/drive/MyDrive/IBMCE CEAGL1IN Certificate _ SmartBridge.pdf
# /content/drive/MyDrive/externship final.pdf
# /content/drive/MyDrive/EP9W62CLAY.png
# /content/drive/MyDrive/L9WFCXMRZN.png
# /content/drive/MyDrive/Details_Form.xlsx
# /content/drive/MyDrive/10715494_Appriciation.pdf
# /content/drive/MyDrive/10715494_Internship.pdf
# /content/drive/MyDrive/Membership Post - The 500 MBA Club (8).png
# /content/drive/MyDrive/IMG_20210929_154304.jpg
# /content/drive/MyDrive/Coursera HRM.pdf
# /content/drive/MyDrive/my_resume_1636004479654-4811330f14de9ac1-converted.pdf
# /content/drive/MyDrive/report 4p3.gdoc
# /content/drive/MyDrive/Sangani Siddhartha.pdf
# /content/drive/MyDrive/Siddhartha_true recruit_internship_certificate.pdf
# /content/drive/MyDrive/IMG-20210407-WA0010.jpg
# /content/drive/MyDrive/EXP_Certificate_SiddharthaSangani-1.pdf
# /content/drive/MyDrive/graphic designer.gsheet
# /content/drive/MyDrive/HR Resume (1).pdf
# /content/drive/MyDrive/HR Resume.pdf
# /content/drive/MyDrive/Aadhar card.pdf
# /content/drive/MyDrive/Sangani_Siddhartha_9390089678.pdf
# /content/drive/MyDrive/memos ..pdf
# /content/drive/MyDrive/Naukri_RajiniR[7y_0m].pdf
# /content/drive/MyDrive/2869014_Sangani Siddhartha (1).pdf
# /content/drive/MyDrive/2869014_Sangani Siddhartha.pdf
# /content/drive/MyDrive/9090164899230112022.pdf
# /content/drive/MyDrive/PROIU-Intern Policy.pdf
# /content/drive/MyDrive/Letter of Intent - Siddhartha Sangani.pdf
# /content/drive/MyDrive/fotor_1674653215931.jpg
# /content/drive/MyDrive/Tech seminar .gdoc
# /content/drive/MyDrive/LTTS Letter of Intent - Sangani Siddhartha_0173.pdf
# /content/drive/MyDrive/LOI LTTS.pdf
# /content/drive/MyDrive/PROIU Letter of Employment & Increment - Siddhartha Sangani (2).pdf
# /content/drive/MyDrive/PROIU-Employment Policy (1).pdf
# /content/drive/MyDrive/PROIU Letter of Employment & Increment - Siddhartha Sangani (1).pdf
# /content/drive/MyDrive/PROIU-Employment Policy.pdf
# /content/drive/MyDrive/PROIU Letter of Employment & Increment - Siddhartha Sangani.pdf
# /content/drive/MyDrive/Cybersecurity Foundation_1683623462482.pdf
# /content/drive/MyDrive/Cloud computing Foundation_1683623441038.pdf
# /content/drive/MyDrive/Artificial Intelligence Foundation_1683623395085.pdf
# /content/drive/MyDrive/IMG_20230521_134558.jpg
# /content/drive/MyDrive/Screenshot_20230521_134809.jpg
# /content/drive/MyDrive/Resume - Siddhartha.pdf
# /content/drive/MyDrive/Notes_230621_111830.gdoc
# /content/drive/MyDrive/SOP for DS.gdoc
# /content/drive/MyDrive/SOP to IS.gdoc
# /content/drive/MyDrive/Daily Dose of Data Science - Archive.pdf
# /content/drive/MyDrive/Adobe Scan Aug 31, 2023.pdf
# /content/drive/MyDrive/  eng with link.pdf
# /content/drive/MyDrive/Screenshot_2023_1017_102630.jpg
# /content/drive/MyDrive/Screenshot_2023_1017_102717.jpg
# /content/drive/MyDrive/Screenshot_2023_1017_102727.jpg
# /content/drive/MyDrive/Wipro .pdf
# /content/drive/MyDrive/Untitled document.gdoc
# /content/drive/MyDrive/PROIU- Experience & Releiving  Certificate - Siddhartha Sangani.pdf
# /content/drive/MyDrive/PROIU- Experience & Releiving  Certificate - Siddhartha Sangani (PM).pdf
# /content/drive/MyDrive/download.jpg
# /content/drive/MyDrive/load.jpg
# /content/drive/MyDrive/download.png
# /content/drive/MyDrive/down.png
# /content/drive/MyDrive/text.png
# /content/drive/MyDrive/lang.jpg
# /content/drive/MyDrive/greeting.mp3
# /content/drive/MyDrive/archive.zip
# /content/drive/MyDrive/grayscale.png
# /content/drive/MyDrive/output.png
# /content/drive/MyDrive/main (1).py
# /content/drive/MyDrive/package.json
# /content/drive/MyDrive/app.py
# /content/drive/MyDrive/main.py
# /content/drive/MyDrive/package-lock.json
# /content/drive/MyDrive/Mini project/final abstract.docx
# /content/drive/MyDrive/Mini project/E10_abstract.pptx
# /content/drive/MyDrive/Mini project/Final PPT.pptx
# /content/drive/MyDrive/Mini project/Smart voting using gui[1][1]###-1-ss.pdf
# /content/drive/MyDrive/Mini project/mat/logindlg.m
# /content/drive/MyDrive/Mini project/mat/license.txt
# /content/drive/MyDrive/Mini project/mat/VotingGUI.fig
# /content/drive/MyDrive/Mini project/mat/VotingGUI.m.txt
# /content/drive/MyDrive/Mini project/mat/GUI mini Project.rar
# /content/drive/MyDrive/Mini project/mat/appdata/compcontents.bin
# /content/drive/MyDrive/Mini project/mat/appdata/prodcontents.bin
# /content/drive/MyDrive/Mini project/mat/appdata/version.xml
# /content/drive/MyDrive/Mini project/mat/appdata/products/CertificateGenerator 1.0 common.xml
# /content/drive/MyDrive/Mini project/mat/appdata/products/CertificateGenerator 1.0 platform.xml
# /content/drive/MyDrive/Mini project/mat/appdata/files/CertificateGenerator_manifest.bin
# /content/drive/MyDrive/Mini project/mat/appdata/components/CertificateGenerator 1.0 common.xml
# /content/drive/MyDrive/Mini project/mat/appdata/components/CertificateGenerator 1.0 platform.xml
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI.fig
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/evmsound.m
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingList.xlsx
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/AdminList.xlsx
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI.m
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI.prj
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/Voting_app.prj
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/PackagingLog.html
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_testing/splash.png
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_testing/mccExcludedFiles.log
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_testing/unresolvedSymbols.txt
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_testing/requiredMCRProducts.txt
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_testing/readme.txt
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_redistribution_files_only/splash.png
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/VotingGUI/for_redistribution_files_only/readme.txt
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/Matlab/GUIBasic.fig
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/Matlab/GUIBasic.m
# /content/drive/MyDrive/Mini project/mat/GUI mini Project/Matlab/app1.mlapp
# /content/drive/MyDrive/Mini project/mat/uninstall/ApplicationInstallerManifest.xml
# /content/drive/MyDrive/Mini project/mat/uninstall/extern/lib/win64/mingw64/libmwi18n.lib
# /content/drive/MyDrive/Mini project/mat/uninstall/extern/lib/win64/microsoft/libmwi18n.lib
# /content/drive/MyDrive/Mini project/mat/uninstall/resources/mcr_uninstaller/en/progresspanel.xml
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/lcdata_utf8.xml
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/lcdata.xsd
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/lcdata.xml
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/icu.rights
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/icuio67.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/zlib1.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwcpp11compat.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/boost.rights
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-datetime-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/zlib.rights
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_system-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-console-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-debug-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-file-l1-2-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/usResourceCompiler3.exe
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-heap-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/ConfigurationAdmin1.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-file-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-errorhandling-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/usLogService.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/jsonschemavalidator.exe
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/SCRCodeGen3.exe
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-file-l2-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-handle-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/usServiceComponent.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-localization-l1-2-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-libraryloader-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-memory-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-interlocked-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-namedpipe-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-processthreads-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-profile-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-processenvironment-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-processthreads-l1-1-1.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-string-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-timezone-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-rtlsupport-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-sysinfo-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-synch-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-synch-l1-2-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-core-util-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-conio-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-heap-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-filesystem-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-convert-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-environment-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-process-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-runtime-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-private-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-math-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-multibyte-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-locale-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-string-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-time-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-utility-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/api-ms-win-crt-stdio-l1-1-0.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/tbbmalloc.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/tbb.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libexpat.rights
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libexpat.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/concrt140.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/vcruntime140_1.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/msvcp140_1.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/vccorlib140.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/msvcp140.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/msvcp140_2.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/vcruntime140.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/msvcp140_codecvt_ids.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libssl-1_1-x64.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_serialization-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_chrono-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_filesystem-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_date_time-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_iostreams-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_atomic-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_timer-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_thread-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/mwboost_log-vc142-mt-x64-1_72.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwfoundation_memmgr.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwlocale.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwresource_core.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwfoundation_filesystem.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/configurations.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/shortcutsapi.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/registrykeyapi.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/instlic_postinstall.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwflcertificates.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwshared_uninstall_utils.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/Uninstall_Application.exe
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/libmwcppmicroservices.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/postinstallservices/install/postinstallservices/shortcutsimpl/mwshortcutsimpl.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/postinstallservices/install/postinstallservices/registrykeyimpl/mwregistrykeyimpl.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/install_configurations/install/app_install_configurations/mwapp_install_configurations.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/win64/cppmicroservices_compendium/foundation/cppmicroservices/logserviceimpl/mwLogServiceImpl.dll
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/icutzdata/zoneinfo64.res
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/icutzdata/metaZones.res
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/icutzdata/windowsZones.res
# /content/drive/MyDrive/Mini project/mat/uninstall/bin/icutzdata/timezoneTypes.res
# /content/drive/MyDrive/Mini project/mat/application/default_icon.ico
# /content/drive/MyDrive/Mini project/mat/application/splash.png
# /content/drive/MyDrive/Mini project/mat/application/readme.txt
# /content/drive/MyDrive/Mini project/Major Project/ZIGBEE BASED WIRELESS TELEMETRY FOR MULTIPLE PATIENTS.doc
# /content/drive/MyDrive/Mini project/Major Project/New Microsoft Office Word Document (2).docx
# /content/drive/MyDrive/Mini project/Major Project/MAJOR PROJECT ABSTRACT.doc
# /content/drive/MyDrive/Mini project/Major Project/MAJOR PROJECT ABSTRACT new.doc
# /content/drive/MyDrive/Mini project/Major Project/E10_abstract.pptx
# /content/drive/MyDrive/Mini project/Major Project/flow chart.pptx
# /content/drive/MyDrive/Mini project/Major Project/E10_30%.pptx
# /content/drive/MyDrive/Mini project/Major Project/report 1.docx
# /content/drive/MyDrive/Mini project/Major Project/Major Project Final Report.pdf
# /content/drive/MyDrive/Mini project/Major Project/Major Project Final Report (1).docx
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/02_Tesseract.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled
# /content/drive/MyDrive/Colab Notebooks/bigdataproject.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/ML Model.ipynb
# /content/drive/MyDrive/Colab Notebooks/UKCompany.ipynb
# /content/drive/MyDrive/Gen AI/FullSizeRender.HEIC
# /content/drive/MyDrive/Gen AI/audio 3.mp3
# /content/drive/MyDrive/Gen AI/download.mp3
# /content/drive/MyDrive/Gen AI/download (1).mp3
# /content/drive/MyDrive/Gen AI/audio1.wav
# /content/drive/MyDrive/Gen AI/aud.wav
# /content/drive/MyDrive/Gen AI/back.HEIC
# /content/drive/MyDrive/Gen AI/back.JPG
# /content/drive/MyDrive/Gen AI/back1.jpg
# /content/drive/MyDrive/Gen AI/back2.jpg
# /content/drive/MyDrive/Gen AI/background.jpeg
# /content/drive/MyDrive/node_modules/.package-lock.json
# /content/drive/MyDrive/node_modules/.bin/lt
# /content/drive/MyDrive/node_modules/axios/LICENSE
# /content/drive/MyDrive/node_modules/axios/index.js
# /content/drive/MyDrive/node_modules/axios/package.json
# /content/drive/MyDrive/node_modules/axios/CHANGELOG.md
# /content/drive/MyDrive/node_modules/axios/README.md
# /content/drive/MyDrive/node_modules/axios/SECURITY.md
# /content/drive/MyDrive/node_modules/axios/UPGRADE_GUIDE.md
# /content/drive/MyDrive/node_modules/axios/index.d.ts
# /content/drive/MyDrive/node_modules/axios/dist/axios.js
# /content/drive/MyDrive/node_modules/axios/dist/axios.min.js
# /content/drive/MyDrive/node_modules/axios/dist/axios.map
# /content/drive/MyDrive/node_modules/axios/dist/axios.min.map
# /content/drive/MyDrive/node_modules/axios/lib/axios.js
# /content/drive/MyDrive/node_modules/axios/lib/defaults.js
# /content/drive/MyDrive/node_modules/axios/lib/utils.js
# /content/drive/MyDrive/node_modules/axios/lib/core/Axios.js
# /content/drive/MyDrive/node_modules/axios/lib/core/buildFullPath.js
# /content/drive/MyDrive/node_modules/axios/lib/core/createError.js
# /content/drive/MyDrive/node_modules/axios/lib/core/dispatchRequest.js
# /content/drive/MyDrive/node_modules/axios/lib/core/enhanceError.js
# /content/drive/MyDrive/node_modules/axios/lib/core/InterceptorManager.js
# /content/drive/MyDrive/node_modules/axios/lib/core/mergeConfig.js
# /content/drive/MyDrive/node_modules/axios/lib/core/settle.js
# /content/drive/MyDrive/node_modules/axios/lib/core/transformData.js
# /content/drive/MyDrive/node_modules/axios/lib/core/README.md
# /content/drive/MyDrive/node_modules/axios/lib/helpers/bind.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/buildURL.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/combineURLs.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/cookies.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/deprecatedMethod.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/isAbsoluteURL.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/isAxiosError.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/isURLSameOrigin.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/normalizeHeaderName.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/parseHeaders.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/spread.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/validator.js
# /content/drive/MyDrive/node_modules/axios/lib/helpers/README.md
# /content/drive/MyDrive/node_modules/axios/lib/cancel/Cancel.js
# /content/drive/MyDrive/node_modules/axios/lib/cancel/CancelToken.js
# /content/drive/MyDrive/node_modules/axios/lib/cancel/isCancel.js
# /content/drive/MyDrive/node_modules/axios/lib/adapters/http.js
# /content/drive/MyDrive/node_modules/axios/lib/adapters/xhr.js
# /content/drive/MyDrive/node_modules/axios/lib/adapters/README.md
# /content/drive/MyDrive/node_modules/debug/LICENSE
# /content/drive/MyDrive/node_modules/debug/package.json
# /content/drive/MyDrive/node_modules/debug/README.md
# /content/drive/MyDrive/node_modules/debug/src/browser.js
# /content/drive/MyDrive/node_modules/debug/src/common.js
# /content/drive/MyDrive/node_modules/debug/src/index.js
# /content/drive/MyDrive/node_modules/debug/src/node.js
# /content/drive/MyDrive/node_modules/openurl/package.json
# /content/drive/MyDrive/node_modules/openurl/.npmignore
# /content/drive/MyDrive/node_modules/openurl/README.md
# /content/drive/MyDrive/node_modules/openurl/openurl.js
# /content/drive/MyDrive/node_modules/yargs/LICENSE
# /content/drive/MyDrive/node_modules/yargs/yargs
# /content/drive/MyDrive/node_modules/yargs/index.cjs
# /content/drive/MyDrive/node_modules/yargs/package.json
# /content/drive/MyDrive/node_modules/yargs/CHANGELOG.md
# /content/drive/MyDrive/node_modules/yargs/README.md
# /content/drive/MyDrive/node_modules/yargs/browser.mjs
# /content/drive/MyDrive/node_modules/yargs/index.mjs
# /content/drive/MyDrive/node_modules/yargs/build/index.cjs
# /content/drive/MyDrive/node_modules/yargs/build/lib/argsert.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/command.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/completion-templates.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/completion.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/middleware.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/parse-command.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/usage.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/validation.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/yargs-factory.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/yerror.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/apply-extends.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/is-promise.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/levenshtein.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/maybe-async-result.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/obj-filter.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/process-argv.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/set-blocking.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/utils/which-module.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/typings/common-types.js
# /content/drive/MyDrive/node_modules/yargs/build/lib/typings/yargs-parser-types.js
# /content/drive/MyDrive/node_modules/yargs/helpers/index.js
# /content/drive/MyDrive/node_modules/yargs/helpers/package.json
# /content/drive/MyDrive/node_modules/yargs/helpers/helpers.mjs
# /content/drive/MyDrive/node_modules/yargs/locales/be.json
# /content/drive/MyDrive/node_modules/yargs/locales/de.json
# /content/drive/MyDrive/node_modules/yargs/locales/en.json
# /content/drive/MyDrive/node_modules/yargs/locales/es.json
# /content/drive/MyDrive/node_modules/yargs/locales/fi.json
# /content/drive/MyDrive/node_modules/yargs/locales/fr.json
# /content/drive/MyDrive/node_modules/yargs/locales/hi.json
# /content/drive/MyDrive/node_modules/yargs/locales/hu.json
# /content/drive/MyDrive/node_modules/yargs/locales/id.json
# /content/drive/MyDrive/node_modules/yargs/locales/it.json
# /content/drive/MyDrive/node_modules/yargs/locales/ja.json
# /content/drive/MyDrive/node_modules/yargs/locales/ko.json
# /content/drive/MyDrive/node_modules/yargs/locales/nb.json
# /content/drive/MyDrive/node_modules/yargs/locales/nl.json
# /content/drive/MyDrive/node_modules/yargs/locales/nn.json
# /content/drive/MyDrive/node_modules/yargs/locales/pirate.json
# /content/drive/MyDrive/node_modules/yargs/locales/pl.json
# /content/drive/MyDrive/node_modules/yargs/locales/pt_BR.json
# /content/drive/MyDrive/node_modules/yargs/locales/pt.json
# /content/drive/MyDrive/node_modules/yargs/locales/ru.json
# /content/drive/MyDrive/node_modules/yargs/locales/th.json
# /content/drive/MyDrive/node_modules/yargs/locales/tr.json
# /content/drive/MyDrive/node_modules/yargs/locales/uk_UA.json
# /content/drive/MyDrive/node_modules/yargs/locales/zh_CN.json
# /content/drive/MyDrive/node_modules/yargs/locales/zh_TW.json
# /content/drive/MyDrive/node_modules/yargs/lib/platform-shims/browser.mjs
# /content/drive/MyDrive/node_modules/yargs/lib/platform-shims/esm.mjs
# /content/drive/MyDrive/node_modules/follow-redirects/LICENSE
# /content/drive/MyDrive/node_modules/follow-redirects/debug.js
# /content/drive/MyDrive/node_modules/follow-redirects/http.js
# /content/drive/MyDrive/node_modules/follow-redirects/https.js
# /content/drive/MyDrive/node_modules/follow-redirects/index.js
# /content/drive/MyDrive/node_modules/follow-redirects/package.json
# /content/drive/MyDrive/node_modules/follow-redirects/README.md
# /content/drive/MyDrive/node_modules/ms/package.json
# /content/drive/MyDrive/node_modules/ms/index.js
# /content/drive/MyDrive/node_modules/ms/license.md
# /content/drive/MyDrive/node_modules/ms/readme.md
# /content/drive/MyDrive/node_modules/cliui/package.json
# /content/drive/MyDrive/node_modules/cliui/CHANGELOG.md
# /content/drive/MyDrive/node_modules/cliui/README.md
# /content/drive/MyDrive/node_modules/cliui/index.mjs
# /content/drive/MyDrive/node_modules/cliui/LICENSE.txt
# /content/drive/MyDrive/node_modules/cliui/build/index.cjs
# /content/drive/MyDrive/node_modules/cliui/build/lib/index.js
# /content/drive/MyDrive/node_modules/cliui/build/lib/string-utils.js
# /content/drive/MyDrive/node_modules/escalade/license
# /content/drive/MyDrive/node_modules/escalade/package.json
# /content/drive/MyDrive/node_modules/escalade/readme.md
# /content/drive/MyDrive/node_modules/escalade/index.d.mts
# /content/drive/MyDrive/node_modules/escalade/index.d.ts
# /content/drive/MyDrive/node_modules/escalade/dist/index.js
# /content/drive/MyDrive/node_modules/escalade/dist/index.mjs
# /content/drive/MyDrive/node_modules/escalade/sync/index.js
# /content/drive/MyDrive/node_modules/escalade/sync/index.mjs
# /content/drive/MyDrive/node_modules/escalade/sync/index.d.mts
# /content/drive/MyDrive/node_modules/escalade/sync/index.d.ts
# /content/drive/MyDrive/node_modules/get-caller-file/package.json
# /content/drive/MyDrive/node_modules/get-caller-file/index.d.ts
# /content/drive/MyDrive/node_modules/get-caller-file/index.js
# /content/drive/MyDrive/node_modules/get-caller-file/index.js.map
# /content/drive/MyDrive/node_modules/get-caller-file/LICENSE.md
# /content/drive/MyDrive/node_modules/get-caller-file/README.md
# /content/drive/MyDrive/node_modules/require-directory/package.json
# /content/drive/MyDrive/node_modules/require-directory/.npmignore
# /content/drive/MyDrive/node_modules/require-directory/LICENSE
# /content/drive/MyDrive/node_modules/require-directory/index.js
# /content/drive/MyDrive/node_modules/require-directory/.jshintrc
# /content/drive/MyDrive/node_modules/require-directory/.travis.yml
# /content/drive/MyDrive/node_modules/require-directory/README.markdown
# /content/drive/MyDrive/node_modules/string-width/license
# /content/drive/MyDrive/node_modules/string-width/index.js
# /content/drive/MyDrive/node_modules/string-width/package.json
# /content/drive/MyDrive/node_modules/string-width/readme.md
# /content/drive/MyDrive/node_modules/string-width/index.d.ts
# /content/drive/MyDrive/node_modules/y18n/LICENSE
# /content/drive/MyDrive/node_modules/y18n/package.json
# /content/drive/MyDrive/node_modules/y18n/CHANGELOG.md
# /content/drive/MyDrive/node_modules/y18n/README.md
# /content/drive/MyDrive/node_modules/y18n/index.mjs
# /content/drive/MyDrive/node_modules/y18n/build/index.cjs
# /content/drive/MyDrive/node_modules/y18n/build/lib/cjs.js
# /content/drive/MyDrive/node_modules/y18n/build/lib/index.js
# /content/drive/MyDrive/node_modules/y18n/build/lib/platform-shims/node.js
# /content/drive/MyDrive/node_modules/yargs-parser/browser.js
# /content/drive/MyDrive/node_modules/yargs-parser/package.json
# /content/drive/MyDrive/node_modules/yargs-parser/CHANGELOG.md
# /content/drive/MyDrive/node_modules/yargs-parser/README.md
# /content/drive/MyDrive/node_modules/yargs-parser/LICENSE.txt
# /content/drive/MyDrive/node_modules/yargs-parser/build/index.cjs
# /content/drive/MyDrive/node_modules/yargs-parser/build/lib/index.js
# /content/drive/MyDrive/node_modules/yargs-parser/build/lib/string-utils.js
# /content/drive/MyDrive/node_modules/yargs-parser/build/lib/tokenize-arg-string.js
# /content/drive/MyDrive/node_modules/yargs-parser/build/lib/yargs-parser-types.js
# /content/drive/MyDrive/node_modules/yargs-parser/build/lib/yargs-parser.js
# /content/drive/MyDrive/node_modules/strip-ansi/license
# /content/drive/MyDrive/node_modules/strip-ansi/index.js
# /content/drive/MyDrive/node_modules/strip-ansi/package.json
# /content/drive/MyDrive/node_modules/strip-ansi/readme.md
# /content/drive/MyDrive/node_modules/strip-ansi/index.d.ts
# /content/drive/MyDrive/node_modules/wrap-ansi/license
# /content/drive/MyDrive/node_modules/wrap-ansi/index.js
# /content/drive/MyDrive/node_modules/wrap-ansi/package.json
# /content/drive/MyDrive/node_modules/wrap-ansi/readme.md
# /content/drive/MyDrive/node_modules/emoji-regex/package.json
# /content/drive/MyDrive/node_modules/emoji-regex/index.d.ts
# /content/drive/MyDrive/node_modules/emoji-regex/index.js
# /content/drive/MyDrive/node_modules/emoji-regex/LICENSE-MIT.txt
# /content/drive/MyDrive/node_modules/emoji-regex/README.md
# /content/drive/MyDrive/node_modules/emoji-regex/text.js
# /content/drive/MyDrive/node_modules/emoji-regex/es2015/index.js
# /content/drive/MyDrive/node_modules/emoji-regex/es2015/text.js
# /content/drive/MyDrive/node_modules/is-fullwidth-code-point/package.json
# /content/drive/MyDrive/node_modules/is-fullwidth-code-point/index.d.ts
# /content/drive/MyDrive/node_modules/is-fullwidth-code-point/index.js
# /content/drive/MyDrive/node_modules/is-fullwidth-code-point/license
# /content/drive/MyDrive/node_modules/is-fullwidth-code-point/readme.md
# /content/drive/MyDrive/node_modules/ansi-regex/license
# /content/drive/MyDrive/node_modules/ansi-regex/index.js
# /content/drive/MyDrive/node_modules/ansi-regex/package.json
# /content/drive/MyDrive/node_modules/ansi-regex/readme.md
# /content/drive/MyDrive/node_modules/ansi-regex/index.d.ts
# /content/drive/MyDrive/node_modules/ansi-styles/license
# /content/drive/MyDrive/node_modules/ansi-styles/index.js
# /content/drive/MyDrive/node_modules/ansi-styles/package.json
# /content/drive/MyDrive/node_modules/ansi-styles/readme.md
# /content/drive/MyDrive/node_modules/ansi-styles/index.d.ts
# /content/drive/MyDrive/node_modules/color-convert/package.json
# /content/drive/MyDrive/node_modules/color-convert/CHANGELOG.md
# /content/drive/MyDrive/node_modules/color-convert/conversions.js
# /content/drive/MyDrive/node_modules/color-convert/index.js
# /content/drive/MyDrive/node_modules/color-convert/LICENSE
# /content/drive/MyDrive/node_modules/color-convert/README.md
# /content/drive/MyDrive/node_modules/color-convert/route.js
# /content/drive/MyDrive/node_modules/color-name/package.json
# /content/drive/MyDrive/node_modules/color-name/index.js
# /content/drive/MyDrive/node_modules/color-name/LICENSE
# /content/drive/MyDrive/node_modules/color-name/README.md
# /content/drive/MyDrive/node_modules/localtunnel/LICENSE
# /content/drive/MyDrive/node_modules/localtunnel/.eslintrc.js
# /content/drive/MyDrive/node_modules/localtunnel/localtunnel.js
# /content/drive/MyDrive/node_modules/localtunnel/localtunnel.spec.js
# /content/drive/MyDrive/node_modules/localtunnel/package.json
# /content/drive/MyDrive/node_modules/localtunnel/CHANGELOG.md
# /content/drive/MyDrive/node_modules/localtunnel/README.md
# /content/drive/MyDrive/node_modules/localtunnel/.travis.yml
# /content/drive/MyDrive/node_modules/localtunnel/lib/HeaderHostTransformer.js
# /content/drive/MyDrive/node_modules/localtunnel/lib/Tunnel.js
# /content/drive/MyDrive/node_modules/localtunnel/lib/TunnelCluster.js
# /content/drive/MyDrive/node_modules/localtunnel/bin/lt.js
# /content/drive/MyDrive/__pycache__/main.cpython-311.pyc
# /content/sample_data/README.md
# /content/sample_data/anscombe.json
# /content/sample_data/california_housing_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/mnist_test.csv

# %%
file_path = "/content/data/corporate_uk/companies_sic_codes.csv"

with open(file_path, 'r', encoding='utf-8') as f:
    for _ in range(10):  # Print first 10 lines
        print(f.readline().strip())
# Out:
# company_number;sic_code;sic_description;sic_section;sic_division;company_url
# 01729565;95110;Repair of computers and peripheral equipment;Other service activities;Repair of computers and personal and household goods;https://corpsignals.com/companies/uk/professional-software-design-ltd-01729565.html
# 01729565;62020;Information technology consultancy activities;Information and communication;Computer programming, consultancy and related activities;https://corpsignals.com/companies/uk/professional-software-design-ltd-01729565.html
# 01729572;74202;Other specialist photography;Professional, scientific and technical activities;Other professional, scientific and technical activities;https://corpsignals.com/companies/uk/apollo-photographers-ltd-01729572.html
# 01729582;98000;Residents property management;"Activities of households as employers; undifferentiated goods-and services-producing activities of households for own use";Undifferentiated goods- and services-producing activities of private households for own use;https://corpsignals.com/companies/uk/24-westbourne-terrace-management-the-company-ltd-01729582.html
# 01729615;98000;Residents property management;"Activities of households as employers; undifferentiated goods-and services-producing activities of households for own use";Undifferentiated goods- and services-producing activities of private households for own use;https://corpsignals.com/companies/uk/lord-roberts-mews-management-ltd-01729615.html
# 01729626;98000;Residents property management;"Activities of households as employers; undifferentiated goods-and services-producing activities of households for own use";Undifferentiated goods- and services-producing activities of private households for own use;https://corpsignals.com/companies/uk/maiden-place-flats-company-ltd-01729626.html
# 01729633;68209;Other letting and operating of own or leased real estate;Real estate activities;Real estate activities;https://corpsignals.com/companies/uk/roman-court-management-co-ltd-01729633.html
# 01729638;49410;Freight transport by road;Transportation and storage;Land transport and transport via pipelines;https://corpsignals.com/companies/uk/allman-transport-services-ltd-01729638.html
# 01729642;41201;Construction of commercial buildings;Construction;Construction of buildings;https://corpsignals.com/companies/uk/chetwynd-mining-and-piling-company-ltd-01729642.html

# %%
import os

# List all files in /content
os.listdir('/content')
# Out:
# ['.config', 'data', 'drive', 'sample_data']

# %%
os.listdir('/content/data/corporate_uk')
# Out:
# ['companies.csv',
#  'filings.csv',
#  'companies_sic_codes.csv',
#  'officers_and_owners.csv']

# %%
import dask.dataframe as dd

# Define file paths and column dtypes
base_path = "/content/data/corporate_uk/"
files = {
    "companies": "companies.csv",
    "sic_codes": "companies_sic_codes.csv",
    "filings": "filings.csv",
    "officers_owners": "officers_and_owners.csv"
}

# Specify the column data types for certain columns to avoid dtype issues
dtype = {
    'company_country': 'object',
    'company_number': 'object'
}

# Load CSV files with the correct separator ";" and dtypes
df_companies = dd.read_csv(base_path + files["companies"], sep=";", encoding="utf-8", assume_missing=True, dtype=dtype)
df_sic_codes = dd.read_csv(base_path + files["sic_codes"], sep=";", encoding="utf-8", assume_missing=True, dtype=dtype) # Apply dtype to df_sic_codes as well
df_filings = dd.read_csv(base_path + files["filings"], sep=";", encoding="utf-8", assume_missing=True, dtype=dtype) # Apply dtype to df_filings as well
df_officers_owners = dd.read_csv(base_path + files["officers_owners"], sep=";", encoding="utf-8", assume_missing=True, dtype=dtype) # Apply dtype to df_officers_owners as well

# %%
# Display first few rows of each DataFrame
df_companies.head(), df_sic_codes.head(), df_filings.head(), df_officers_owners.head()
# Out:
# (  company_number             company_type  \
#  0       13511884  Private limited company
#  1       13511885  Private limited company
#  2       13511887  Private limited company
#  3       13511889  Private limited company
#  4       13511892  Private limited company
#
#                                        office_address incorporation_date  \
#  0  CM20 1YS, England, Harlow, Essex, C/O Aacsl Ac...         2021-07-15
#  1  RH2 7JN, England, Reigate, Surrey, Chart House...         2021-07-15
#  2    RM8 1PS, England, Dagenham, 31 Lamberhurst Road         2021-07-15
#  3      DA12 2RX, England, Gravesend, 11 Norfolk Road         2021-07-15
#  4  UB10 0NX, England, Hillingdon, 1 Agincourt Vil...         2021-07-15
#
#      jurisdiction company_status          account_type  \
#  0  England/Wales      Dissolved          Micro Entity
#  1  England/Wales         Active          Micro Entity
#  2  England/Wales         Active          Micro Entity
#  3  England/Wales         Active          Micro Entity
#  4  England/Wales         Active  Total Exemption Full
#
#                     company_name                     sic_codes  \
#  0              Nocik Health Ltd                [86210, 86900]
#  1             Jfs Group Limited                       [64203]
#  2            Samara Trading Ltd         [49320, 49410, 51102]
#  3  Quantum Brooks Logistics Ltd  [49410, 50200, 51210, 52101]
#  4                      Pbkn Ltd                       [56101]
#
#    date_of_cessation next_accounts_overdue confirmation_statement_overdue  \
#  0        2024-06-18                  <NA>                           <NA>
#  1              <NA>                  True                           <NA>
#  2              <NA>                  <NA>                           <NA>
#  3              <NA>                  <NA>                           <NA>
#  4              <NA>                  <NA>                           <NA>
#
#     owners  officers  average_number_employees_during_period  current_assets  \
#  0     1.0       1.0                                     0.0         17602.0
#  1     1.0       1.0                                     0.0             NaN
#  2     1.0       1.0                                     1.0          1307.0
#  3     2.0       2.0                                     2.0           236.0
#  4     1.0       1.0                                     5.0         37863.0
#
#    last_accounts_period_end                                        company_url
#  0               2023-12-31  https://corpsignals.com/companies/uk/nocik-hea...
#  1               2022-07-31  https://corpsignals.com/companies/uk/jfs-group...
#  2               2023-03-31  https://corpsignals.com/companies/uk/samara-tr...
#  3               2023-07-31  https://corpsignals.com/companies/uk/quantum-b...
#  4               2023-07-31  https://corpsignals.com/companies/uk/pbkn-ltd-...  ,
#    company_number  sic_code                                sic_description  \
#  0       01729565   95110.0   Repair of computers and peripheral equipment
#  1       01729565   62020.0  Information technology consultancy activities
#  2       01729572   74202.0                   Other specialist photography
#  3       01729582   98000.0                  Residents property management
#  4       01729615   98000.0                  Residents property management
#
#                                           sic_section  \
#  0                           Other service activities
#  1                      Information and communication
#  2  Professional, scientific and technical activities
#  3  Activities of households as employers; undiffe...
#  4  Activities of households as employers; undiffe...
#
#                                          sic_division  \
#  0  Repair of computers and personal and household...
#  1  Computer programming, consultancy and related ...
#  2  Other professional, scientific and technical a...
#  3  Undifferentiated goods- and services-producing...
#  4  Undifferentiated goods- and services-producing...
#
#                                           company_url
#  0  https://corpsignals.com/companies/uk/professio...
#  1  https://corpsignals.com/companies/uk/professio...
#  2  https://corpsignals.com/companies/uk/apollo-ph...
#  3  https://corpsignals.com/companies/uk/24-westbo...
#  4  https://corpsignals.com/companies/uk/lord-robe...  ,
#    company_number        date                category  pages  \
#  0       00000086  2023-12-13                accounts   10.0
#  1       00000086  2023-09-28                mortgage    1.0
#  2       00000086  2023-09-21  confirmation statement   28.0
#  3       00000086  2023-06-01                mortgage    1.0
#  4       00000086  2023-05-02                officers    2.0
#
#                                           description
#  0  Accounts for a small company made up to 2023-0...
#  1        Satisfaction of charge 000000860062 in full
#  2  Confirmation statement made on 2023-09-19 with...
#  3        Satisfaction of charge 000000860069 in full
#  4  Appointment of Mr Peter Searle as a director o...  ,
#    company_number                  name        kind officer_role  \
#  0       12022282  Laurence Justin Mark  individual     Director
#  1       12022305  Peters Chris William  individual     Director
#  2       12022363      Marcelo Stefanie  individual     Director
#  3       12022384       Singh Harsimran  individual     Director
#  4       12022410        Mateo Lamberto  individual     Director
#
#           occupation        date  is_owner country_of_residence nationality  \
#  0   project manager  2019-05-29     False       United Kingdom     British
#  1  company director  2019-05-29     False       United Kingdom     British
#  2          director  2019-06-30     False          Philippines    Filipino
#  3            retail  2019-05-29     False              England     British
#  4          director  2019-06-24     False          Philippines    Filipino
#
#    company_country  person_id  \
#  0            <NA>  4233524.0
#  1            <NA>  3742466.0
#  2            <NA>   313465.0
#  3            <NA>  1122380.0
#  4            <NA>  2456488.0
#
#                                            person_url
#  0  https://corpsignals.com/persons/uk/laurence-ju...
#  1  https://corpsignals.com/persons/uk/peters-chri...
#  2  https://corpsignals.com/persons/uk/marcelo-ste...
#  3  https://corpsignals.com/persons/uk/singh-harsi...
#  4  https://corpsignals.com/persons/uk/mateo-lambe...  )

# %%
# Check column names and data types for each DataFrame
df_companies.compute().info()
df_sic_codes.compute().info()
df_filings.compute().info()
df_officers_owners.compute().info()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# <class 'pandas.core.frame.DataFrame'>
# Index: 5428900 entries, 0 to 253929
# Data columns (total 18 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   company_number                          string
#  1   company_type                            string
#  2   office_address                          string
#  3   incorporation_date                      string
#  4   jurisdiction                            string
#  5   company_status                          string
#  6   account_type                            string
#  7   company_name                            string
#  8   sic_codes                               string
#  9   date_of_cessation                       string
#  10  next_accounts_overdue                   string
#  11  confirmation_statement_overdue          string
#  12  owners                                  float64
#  13  officers                                float64
#  14  average_number_employees_during_period  float64
#  15  current_assets                          float64
#  16  last_accounts_period_end                string
#  17  company_url                             string
# dtypes: float64(4), string(14)
# memory usage: 2.0 GB
# <class 'pandas.core.frame.DataFrame'>
# Index: 7856665 entries, 0 to 335367
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   company_number   string
#  1   sic_code         float64
#  2   sic_description  string
#  3   sic_section      string
#  4   sic_division     string
#  5   company_url      string
# dtypes: float64(1), string(5)
# memory usage: 1.9 GB
# <class 'pandas.core.frame.DataFrame'>
# Index: 22535531 entries, 0 to 717484
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   company_number  string
#  1   date            string
#  2   category        string
#  3   pages           float64
#  4   description     string
# dtypes: float64(1), string(4)
# memory usage: 2.9 GB
# <class 'pandas.core.frame.DataFrame'>
# Index: 10519812 entries, 0 to 388092
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   company_number        string
#  1   name                  string
#  2   kind                  string
#  3   officer_role          string
#  4   occupation            string
#  5   date                  string
#  6   is_owner              bool
#  7   country_of_residence  string
#  8   nationality           string
#  9   company_country       string
#  10  person_id             float64
#  11  person_url            string
# dtypes: bool(1), float64(1), string(10)
# memory usage: 2.4 GB

# %%
import dask.dataframe as dd




# Check for duplicate rows using `drop_duplicates` and comparing lengths
def check_duplicates(df):
    """Checks for duplicates in a Dask DataFrame by comparing lengths before and after drop_duplicates."""
    original_len = len(df)  # Get the original length
    unique_len = len(df.drop_duplicates())  # Get the length after dropping duplicates
    duplicates_count = original_len - unique_len  # Calculate the number of duplicates
    return duplicates_count

# Calculate and print the duplicate counts for each DataFrame
companies_duplicates = check_duplicates(df_companies)
sic_codes_duplicates = check_duplicates(df_sic_codes)
filings_duplicates = check_duplicates(df_filings)
officers_owners_duplicates = check_duplicates(df_officers_owners)

print(f"Duplicate rows in df_companies: {companies_duplicates}")
print(f"Duplicate rows in df_sic_codes: {sic_codes_duplicates}")
print(f"Duplicate rows in df_filings: {filings_duplicates}")
print(f"Duplicate rows in df_officers_owners: {officers_owners_duplicates}")
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# Duplicate rows in df_companies: 0
# Duplicate rows in df_sic_codes: 0
# Duplicate rows in df_filings: 35085
# Duplicate rows in df_officers_owners: 7312

# %%
# Drop duplicate rows
df_companies = df_companies.drop_duplicates()
df_sic_codes = df_sic_codes.drop_duplicates()
df_filings = df_filings.drop_duplicates()
df_officers_owners = df_officers_owners.drop_duplicates()

# %%
# Check for missing values again
df_companies.isnull().sum().compute(), df_sic_codes.isnull().sum().compute(), df_filings.isnull().sum().compute(), df_officers_owners.isnull().sum().compute()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# (company_number                                  0
#  company_type                                    0
#  office_address                               1140
#  incorporation_date                              0
#  jurisdiction                                 1382
#  company_status                                  0
#  account_type                               365376
#  company_name                                    1
#  sic_codes                                  170628
#  date_of_cessation                         4873614
#  next_accounts_overdue                     4537891
#  confirmation_statement_overdue            4441448
#  owners                                     373081
#  officers                                   143828
#  average_number_employees_during_period    2072106
#  current_assets                            2533928
#  last_accounts_period_end                  1462068
#  company_url                                     0
#  dtype: int64,
#  company_number     0
#  sic_code           0
#  sic_description    0
#  sic_section        0
#  sic_division       0
#  company_url        0
#  dtype: int64,
#  company_number     0
#  date               0
#  category           8
#  pages              0
#  description       15
#  dtype: int64,
#  company_number                0
#  name                         10
#  kind                          0
#  officer_role            1393364
#  occupation              2566588
#  date                          0
#  is_owner                      0
#  country_of_residence    1717043
#  nationality             1488859
#  company_country         9808545
#  person_id                     0
#  person_url                    0
#  dtype: int64)

# %%
# Drop rows with any missing values
df_companies = df_companies.dropna()
df_sic_codes = df_sic_codes.dropna()
df_filings = df_filings.dropna()
df_officers_owners = df_officers_owners.dropna()

# %%
# Check for missing values again
df_companies.isnull().sum().compute(), df_sic_codes.isnull().sum().compute(), df_filings.isnull().sum().compute(), df_officers_owners.isnull().sum().compute()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# (company_number                            0
#  company_type                              0
#  office_address                            0
#  incorporation_date                        0
#  jurisdiction                              0
#  company_status                            0
#  account_type                              0
#  company_name                              0
#  sic_codes                                 0
#  date_of_cessation                         0
#  next_accounts_overdue                     0
#  confirmation_statement_overdue            0
#  owners                                    0
#  officers                                  0
#  average_number_employees_during_period    0
#  current_assets                            0
#  last_accounts_period_end                  0
#  company_url                               0
#  dtype: int64,
#  company_number     0
#  sic_code           0
#  sic_description    0
#  sic_section        0
#  sic_division       0
#  company_url        0
#  dtype: int64,
#  company_number    0
#  date              0
#  category          0
#  pages             0
#  description       0
#  dtype: int64,
#  company_number          0
#  name                    0
#  kind                    0
#  officer_role            0
#  occupation              0
#  date                    0
#  is_owner                0
#  country_of_residence    0
#  nationality             0
#  company_country         0
#  person_id               0
#  person_url              0
#  dtype: int64)

# %%
# Check the actual column names in the DataFrame
print(df_companies.columns)

# Assuming the correct column name is 'incorporation_date', modify the code as follows:
df_companies['incorporation_date'] = dd.to_datetime(df_companies['incorporation_date'], errors='coerce')
# Out:
# Index(['company_number', 'company_type', 'office_address',
#        'incorporation_date', 'jurisdiction', 'company_status', 'account_type',
#        'company_name', 'sic_codes', 'date_of_cessation',
#        'next_accounts_overdue', 'confirmation_statement_overdue', 'owners',
#        'officers', 'average_number_employees_during_period', 'current_assets',
#        'last_accounts_period_end', 'company_url'],
#       dtype='object')

# %%
# Convert the 'incorporation_date' to datetime, coercing errors into NaT (Not a Time) for invalid values
import dask.dataframe as dd # Import the dask.dataframe module and assign it to the alias 'dd'
df_companies['incorporation_date'] = dd.to_datetime(df_companies['incorporation_date'], errors='coerce')

# Check the updated data
# Compute the entire result before calling head()
result = df_companies[['company_number', 'company_name', 'incorporation_date']].compute()
result.head() # Call head on the Pandas DataFrame 'result'
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#        company_number                     company_name incorporation_date
# 29137        11542049  Doctors Of Optimization Limited         2018-08-29
# 65753        10177944              Clever Clogs Ip Ltd         2016-05-13
# 214384       10228149  Empreo Property Holding Limited         2016-06-13
# 5277         10231937     Evans Building Solutions Ltd         2016-06-14
# 124562       11384074                Chapter I Limited         2018-05-25

# %%
# Convert 'date_of_cessation' to datetime with error handling
df_companies['date_of_cessation'] = dd.to_datetime(df_companies['date_of_cessation'], errors='coerce')

# Extract year from incorporation_date and date_of_cessation
df_companies['incorporation_year'] = df_companies['incorporation_date'].dt.year
df_companies['closure_year'] = df_companies['date_of_cessation'].dt.year

# Display first few rows to verify
df_companies[['company_number', 'incorporation_year', 'closure_year']].head()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#        company_number  incorporation_year  closure_year
# 29137        11542049                2018          2020
# 65753        10177944                2016          2017
# 214384       10228149                2016          2023
# 5277         10231937                2016          2018
# 124562       11384074                2018          2021

# %%
import matplotlib.pyplot as plt

# Group by incorporation year and count companies
formations_per_year = df_companies.groupby('incorporation_year').size().compute()

# Group by closure year and count closed companies
closures_per_year = df_companies.groupby('closure_year').size().compute()

# Convert to DataFrame for easier plotting
df_formations = formations_per_year.reset_index(name='num_companies_formed')
df_closures = closures_per_year.reset_index(name='num_companies_closed')

# Display first few rows to verify
df_formations.head(), df_closures.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# (   incorporation_year  num_companies_formed
#  0                1995                     4
#  1                2000                    13
#  2                2002                    11
#  3                2008                    19
#  4                2012                    88,
#     closure_year  num_companies_closed
#  0          2015                    84
#  1          2016                   167
#  2          2019                   268
#  3          2022                   221
#  4          2014                    52)

# %%
plt.figure(figsize=(12, 6))

# Plot formations
plt.plot(df_formations['incorporation_year'], df_formations['num_companies_formed'], label='Companies Formed', marker='o')

# Plot closures
plt.plot(df_closures['closure_year'], df_closures['num_companies_closed'], label='Companies Closed', marker='s')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Companies')
plt.title('Company Formations and Closures Over Time')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
# Count occurrences of each SIC code
# Check the actual column names in df_sic_codes
print(df_sic_codes.columns)

# Access the column by its actual name, it might be 'SICCode', 'sic_code', or similar
# Replace 'sic_code' with the correct column name from the output above
industry_counts = df_sic_codes['sic_code'].value_counts().compute()

# Convert to DataFrame for easier plotting
df_industry_counts = industry_counts.reset_index()
df_industry_counts.columns = ['SIC Code', 'Number of Companies']

# Display top 10 industries
df_industry_counts.head(10)
# Out:
# Index(['company_number', 'sic_code', 'sic_description', 'sic_section',
#        'sic_division', 'company_url'],
#       dtype='object')
#    SIC Code  Number of Companies
# 0    1140.0                  188
# 1    3210.0                  692
# 2   10620.0                   56
# 3   10821.0                 1091
# 4   11070.0                 1939
# 5   13200.0                  826
# 6   13990.0                 2298
# 7   15200.0                  925
# 8   17220.0                  626
# 9   24440.0                   82

# %%
# Check for missing values in the 'office_address' column
missing_values = df_companies['office_address'].isnull().sum().compute()
print(f"Missing values in 'office_address' column: {missing_values}")
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# Missing values in 'office_address' column: 0

# %%
# Check unique values in the 'office_address' column
unique_regions = df_companies['office_address'].unique().compute()
print(unique_regions[:10])  # Show first 10 unique regions
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# 0    KT13 9PY, England, Weybridge, Surrey, 4 Pantil...
# 1    BL6 4SD, Bolton, Cowgill Holloway Business Rec...
# 2    L3 6BN, United Kingdom, Liverpool, 85-87 Vauxh...
# 3      CR0 2UF, Croydon, Surrey, 55 Kidderminster Road
# 4    UB5 5JS, United Kingdom, Northolt, Middlesex, ...
# 5    B73 5PR, England, Coldfield, West Midlands, 7 ...
# 6       BR6 0QF, England, Orpington, 50 Lodge Crescent
# 7    RM9 6RT, United Kingdom, Dagenham, 2 Chequers ...
# 8        TW1 1JP, Twickenham, Richmond, 45 Sidney Road
# 9    RM1 1TE, England, Romford, Essex, 2nd Floor 13...
# Name: office_address, dtype: string

# %%
import matplotlib.pyplot as plt
import dask.dataframe as dd

# Assuming 'office_address' contains region information
# Extract region information and count occurrences
region_counts = df_companies['office_address'].value_counts().compute()

# Convert to DataFrame for easier plotting
df_region_counts = region_counts.reset_index()
df_region_counts.columns = ['Region', 'Number of Companies']

# Select the top 10 regions
top_10_regions = df_region_counts.head(10)

# Plot regions as a pie chart
plt.figure(figsize=(8, 8))  # Adjust figure size as needed
plt.pie(top_10_regions['Number of Companies'], labels=top_10_regions['Region'], autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Regions with the Most Companies')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %%
# Check column names in df_companies
print(df_companies.columns)

# Replace 'region_column' with the actual column name related to the company’s location
region_counts = df_companies['office_address'].value_counts().compute()

# Convert to DataFrame
df_region_counts = region_counts.reset_index()
df_region_counts.columns = ['Region', 'Number of Companies']

# Display top 10 regions
df_region_counts.head(10)
# Out:
# Index(['company_number', 'company_type', 'office_address',
#        'incorporation_date', 'jurisdiction', 'company_status', 'account_type',
#        'company_name', 'sic_codes', 'date_of_cessation',
#        'next_accounts_overdue', 'confirmation_statement_overdue', 'owners',
#        'officers', 'average_number_employees_during_period', 'current_assets',
#        'last_accounts_period_end', 'company_url', 'incorporation_year',
#        'closure_year'],
#       dtype='object')
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#                                               Region  Number of Companies
# 0     AL4 9TX, England, St. Albans, 503 The Ridgeway                    1
# 1  B73 5PR, England, Coldfield, West Midlands, 7 ...                    1
# 2  BA22 7LZ, United Kingdom, Yeovil, Somerset, Th...                    1
# 3  BL6 4SD, Bolton, Cowgill Holloway Business Rec...                    1
# 4  BN1 3JG, England, Brighton, East Sussex, F3, 8...                    1
# 5     BR6 0QF, England, Orpington, 50 Lodge Crescent                    1
# 6  BS7 9AR, Bristol, 1 Newland Heights, Balmoral ...                    1
# 7  BT1 6JH, Northern Ireland, Belfast, Scottish P...                    1
# 8         BT35 8QX, Newry, Co Down, 56 Forkhill Road                    1
# 9  CF14 8LH, Cardiff, 09762347: COMPANIES HOUSE D...                    1

# %%
# Group by 'incorporation_year' to get the number of formations per year
formation_counts = df_companies['incorporation_year'].value_counts().compute()

# Group by 'closure_year' to get the number of closures per year
closure_counts = df_companies['closure_year'].value_counts().compute()

# Convert to DataFrame for easier plotting
df_formation_counts = formation_counts.reset_index()
df_formation_counts.columns = ['Year', 'Number of Formations']

df_closure_counts = closure_counts.reset_index()
df_closure_counts.columns = ['Year', 'Number of Closures']

# Display top 5 rows of both
print(df_formation_counts.head(), df_closure_counts.head())
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#    Year  Number of Formations
# 0  1930                     1
# 1  1934                     1
# 2  1962                     1
# 3  2010                    47
# 4  1973                     1    Year  Number of Closures
# 0  2019                 268
# 1  2021                 215
# 2  2012                   3
# 3  2023                 202
# 4  2017                 163

# %%
# Filter companies that have valid formation year
df_formations = df_companies[df_companies['incorporation_year'].notnull()]

# Extract region information from office_address and aggregate by year and region
# Apply map_partitions to perform str.extract on each partition of the Dask DataFrame
df_formations['region'] = df_formations['office_address'].map_partitions(lambda df: df.str.extract(r'([A-Za-z\s]+)', expand=False), meta=('region', 'object'))  # Adjust the regex as needed
df_formations_grouped = df_formations.groupby(['incorporation_year', 'region']).size().reset_index()
# Rename the '0' column to 'Number of Companies' after reset_index
df_formations_grouped = df_formations_grouped.rename(columns={0: 'Number of Companies'})

# Display the formation counts by year and region
df_formations_grouped.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#    incorporation_year region  Number of Companies
# 0                1987     TN                    1
# 1                2002     NW                    2
# 2                2005     SO                    1
# 3                2008     SK                    1
# 4                2009      B                    2

# %%
# Filter companies that have valid closure year (date_of_cessation)
df_closures = df_companies[df_companies['closure_year'].notnull()]

# Extract region information from office_address for closures
# Use map_partitions to apply str.extract on each partition
df_closures['region'] = df_closures['office_address'].map_partitions(lambda df: df.str.extract(r'([A-Za-z\s]+)', expand=False), meta=('region', 'object'))  # Adjust the regex as needed

df_closures_grouped = df_closures.groupby(['closure_year', 'region']).size().reset_index()
# Rename the '0' column to 'Number of Companies' after reset_index
df_closures_grouped = df_closures_grouped.rename(columns={0: 'Number of Companies'})

# Display the closure counts by year and region
df_closures_grouped.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#    closure_year region  Number of Companies
# 0          2015     KA                    1
# 1          2015     PO                    3
# 2          2016     CR                    4
# 3          2016     HA                    7
# 4          2016     SW                    5

# %%
# Plot company formations by year and region
plt.figure(figsize=(12, 6))
# Compute the sum and then sort
top_regions_formations = df_formations_grouped.groupby('region')['Number of Companies'].sum().compute().sort_values(ascending=False).head(10)

plt.barh(top_regions_formations.index, top_regions_formations.values, color='lightgreen')
plt.xlabel('Number of Companies Formed')
plt.ylabel('Region')
plt.title('Top Regions for Company Formations')
plt.gca().invert_yaxis()  # Invert to show the highest at the top
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %%
# Plot company closures by year and region
plt.figure(figsize=(12, 6))

# Compute the sum and convert it to a Pandas Series before sorting
top_regions_closures = df_closures_grouped.groupby('region')['Number of Companies'].sum().compute()
# Now you have a Pandas Series, so you can use sort_values
top_regions_closures = top_regions_closures.sort_values(ascending=False).head(10)

plt.barh(top_regions_closures.index, top_regions_closures.values, color='salmon')
plt.xlabel('Number of Companies Closed')
plt.ylabel('Region')
plt.title('Top Regions for Company Closures')
plt.gca().invert_yaxis()  # Invert to show the highest at the top
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %%
# Merge companies data with SIC codes to get industries
df_formations_industry = df_formations.merge(df_sic_codes, on='company_number', how='left')

# Count the most common industries for newly formed companies
top_industries_formations = df_formations_industry['sic_code'].value_counts().compute().head(10)

# Convert to DataFrame
df_top_industries_formations = top_industries_formations.reset_index()
df_top_industries_formations.columns = ['SIC Code', 'Number of Companies Formed']

# Display top 10 industries for formations
df_top_industries_formations
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#    SIC Code  Number of Companies Formed
# 0   13990.0                           2
# 1   42130.0                           1
# 2   43999.0                          31
# 3   46380.0                           2
# 4   47730.0                           1
# 5   56103.0                          37
# 6   59112.0                           5
# 7   74909.0                          33
# 8   77291.0                           1
# 9   88910.0                           1

# %%
# Merge companies with SIC codes
df_formed = df_companies.merge(df_sic_codes, on='company_number', how='left')

# Compute Dask DataFrame to get a Pandas DataFrame
df_formed = df_formed.compute()

# Filter only formed companies (you can also filter by year if needed)
df_formed = df_formed[~df_formed['incorporation_year'].isna()]

# Count companies formed per industry
industry_formed = df_formed.groupby('sic_code')['company_number'].count().reset_index()
industry_formed.columns = ['SIC Code', 'Companies Formed']

# Sort top 10 industries
top_formed_industries = industry_formed.sort_values(by='Companies Formed', ascending=False).head(10)

# Show results
top_formed_industries
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#      SIC Code  Companies Formed
# 267   82990.0               109
# 217   70229.0                88
# 184   62020.0                75
# 208   68209.0                70
# 315   96090.0                64
# 206   68100.0                52
# 54    41100.0                48
# 56    41202.0                45
# 160   56103.0                37
# 186   62090.0                35

# %%
# Filter closed companies from merged dataset
# Assuming 'date_of_cessation' indicates closure
df_closed = df_formed[~df_formed['date_of_cessation'].isna()]

# Count companies closed per industry
industry_closed = df_closed.groupby('sic_code')['company_number'].count().reset_index()
industry_closed.columns = ['SIC Code', 'Companies Closed']

# Sort top 10 industries
top_closed_industries = industry_closed.sort_values(by='Companies Closed', ascending=False).head(10)

# Show results
top_closed_industries
# Out:
#      SIC Code  Companies Closed
# 267   82990.0               109
# 217   70229.0                88
# 184   62020.0                75
# 208   68209.0                70
# 315   96090.0                64
# 206   68100.0                52
# 54    41100.0                48
# 56    41202.0                45
# 160   56103.0                37
# 186   62090.0                35

# %%
# Merge companies with SIC codes
df_formed = df_companies.merge(df_sic_codes, on='company_number', how='left')

# Compute Dask DataFrame to get a Pandas DataFrame
df_formed = df_formed.compute()

# Filter only formed companies (you can also filter by year if needed)
df_formed = df_formed[~df_formed['incorporation_year'].isna()]

# Count companies formed per industry
industry_formed = df_formed.groupby('sic_code')['company_number'].count().reset_index()
industry_formed.columns = ['SIC Code', 'Companies Formed']

# Sort top 10 industries
top_formed_industries = industry_formed.sort_values(by='Companies Formed', ascending=False).head(10)

# Show results
print("Top Formed Industries:")
print(top_formed_industries)

# --- Changes for closed companies ---

# Filter closed companies from merged dataset
# Instead of checking date_of_cessation, check if company_status is 'dissolved'
df_closed = df_formed[df_formed['company_status'] == 'dissolved']

# Check if 'company_status' column is available, otherwise use 'date_of_cessation'
if 'company_status' not in df_formed.columns:
    df_closed = df_formed[~df_formed['date_of_cessation'].isna()]

# Count companies closed per industry
industry_closed = df_closed.groupby('sic_code')['company_number'].count().reset_index()
industry_closed.columns = ['SIC Code', 'Companies Closed']

# Sort top 10 industries
top_closed_industries = industry_closed.sort_values(by='Companies Closed', ascending=False).head(10)

# Show results
print("\nTop Closed Industries:")
print(top_closed_industries)
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# Top Formed Industries:
#      SIC Code  Companies Formed
# 267   82990.0               109
# 217   70229.0                88
# 184   62020.0                75
# 208   68209.0                70
# 315   96090.0                64
# 206   68100.0                52
# 54    41100.0                48
# 56    41202.0                45
# 160   56103.0                37
# 186   62090.0                35
#
# Top Closed Industries:
# Empty DataFrame
# Columns: [SIC Code, Companies Closed]
# Index: []

# %%
# Merge closed companies with SIC codes
df_closures_industry = df_closures.merge(df_sic_codes, on='company_number', how='left')

# Count the most common industries for closed companies
top_industries_closures = df_closures_industry['sic_code'].value_counts().compute().head(10)

# Convert to DataFrame
df_top_industries_closures = top_industries_closures.reset_index()
df_top_industries_closures.columns = ['SIC Code', 'Number of Companies Closed']

# Display top 10 industries for closures
df_top_industries_closures
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#    SIC Code  Number of Companies Closed
# 0   13990.0                           2
# 1   42130.0                           1
# 2   43999.0                          31
# 3   46380.0                           2
# 4   47730.0                           1
# 5   56103.0                          37
# 6   59112.0                           5
# 7   74909.0                          33
# 8   77291.0                           1
# 9   88910.0                           1

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Merge closed companies data with SIC codes to get industries
df_closures_industry = df_closures.merge(df_sic_codes, on='company_number', how='left')

# Count the most common industries for closed companies
top_industries_closures = df_closures_industry['sic_code'].value_counts().compute().head(10)

# Convert to DataFrame
df_top_industries_closures = top_industries_closures.reset_index()
df_top_industries_closures.columns = ['SIC Code', 'Number of Companies Closed']

# --- Plot: Company Closures by SIC Code ---
plt.figure(figsize=(12, 6))
plt.bar(df_top_industries_closures['SIC Code'], df_top_industries_closures['Number of Companies Closed'], color='salmon')
plt.xlabel('SIC Code')
plt.ylabel('Number of Companies Closed')
plt.title('Top 10 Industries with the Most Company Closures')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# --- Optional: Display the DataFrame ---
# If you want to see the actual data in the DataFrame:
display(df_top_industries_closures)
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
#    SIC Code  Number of Companies Closed
# 0   13990.0                           2
# 1   42130.0                           1
# 2   43999.0                          31
# 3   46380.0                           2
# 4   47730.0                           1
# 5   56103.0                          37
# 6   59112.0                           5
# 7   74909.0                          33
# 8   77291.0                           1
# 9   88910.0                           1

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot formations
# Use 'Number of Companies' instead of 'num_companies_formed'
plt.plot(df_formations_grouped['incorporation_year'].compute(),
         df_formations_grouped['Number of Companies'].compute(),
         label='Companies Formed', marker='o')

# Plot closures
# Assuming df_closures has a similar structure, replace 'num_companies_closed' with the actual column name
plt.plot(df_closures_grouped['closure_year'].compute(),
         df_closures_grouped['Number of Companies'].compute(),
         label='Companies Closed', marker='s')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Number of Companies')
plt.title('Company Formations and Closures Over Time')
plt.legend()
plt.grid(True)

# Show plot
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %%
plt.figure(figsize=(8, 8))
plt.pie(df_top_industries_closures['Number of Companies Closed'], labels=df_top_industries_closures['SIC Code'], autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Industry Distribution for Company Closures')
plt.show()

# %%
import matplotlib.pyplot as plt

# --- Plot 1: Company Formations ---
plt.figure(figsize=(12, 6))
# Access the correct column for company formations, likely 'Number of Companies'
# Convert Dask Series to NumPy arrays before plotting
plt.plot(df_formations_grouped['incorporation_year'].compute(),
         df_formations_grouped['Number of Companies'].compute(),
         label='Companies Formed', marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Companies Formed')
plt.title('Company Formations Over Time')
plt.legend()
plt.grid(True)
plt.show()

# --- Plot 2: Company Closures ---
plt.figure(figsize=(12, 6))
# Access the correct column for company closures, likely 'Number of Companies'
# Convert Dask Series to NumPy arrays before plotting
plt.plot(df_closures_grouped['closure_year'].compute(),
         df_closures_grouped['Number of Companies'].compute(),
         label='Companies Closed', marker='s', color='red')  # Red color for closures
plt.xlabel('Year')
plt.ylabel('Number of Companies Closed')
plt.title('Company Closures Over Time')
plt.legend()
plt.grid(True)
plt.show()

# --- Plot 3: Combined Formations and Closures ---
plt.figure(figsize=(12, 6))

# Aggregate formations and closures by year to enable plotting on the same graph
formations_by_year = df_formations_grouped.groupby('incorporation_year')['Number of Companies'].sum().compute()
closures_by_year = df_closures_grouped.groupby('closure_year')['Number of Companies'].sum().compute()

# Convert Pandas Series to NumPy arrays for plotting
plt.plot(formations_by_year.index.to_numpy(), formations_by_year.values, label='Companies Formed', marker='o')
plt.plot(closures_by_year.index.to_numpy(), closures_by_year.values, label='Companies Closed', marker='s', color='red')  # Red color for closures

plt.xlabel('Year')
plt.ylabel('Number of Companies')
plt.title('Company Formations and Closures Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/io/csv.py:199: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = reader(bio, **kwargs)

# %% [markdown]
# sic code

# %%
# Get top 5 most common SIC codes
top_sics = df_merged_pd['sic_code'].value_counts().nlargest(5).index
df_filtered = df_merged_pd[df_merged_pd['sic_code'].isin(top_sics)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-40089cb94517> in <cell line: 0>()
#       1 # Get top 5 most common SIC codes
# ----> 2 top_sics = df_merged_pd['sic_code'].value_counts().nlargest(5).index
#       3 df_filtered = df_merged_pd[df_merged_pd['sic_code'].isin(top_sics)]
#
# NameError: name 'df_merged_pd' is not defined

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df_filtered, x='incorporation_year', hue='sic_code')
plt.title('Company Formations Over Years by SIC Code')
plt.xlabel('Year')
plt.ylabel('Number of Companies Formed')
plt.xticks(rotation=45)
plt.legend(title='SIC Code')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-6527a42a0a7d> in <cell line: 0>()
#       1 plt.figure(figsize=(12, 6))
# ----> 2 sns.countplot(data=df_filtered, x='incorporation_year', hue='sic_code')
#       3 plt.title('Company Formations Over Years by SIC Code')
#       4 plt.xlabel('Year')
#       5 plt.ylabel('Number of Companies Formed')
#
# NameError: name 'sns' is not defined

# %%
# Pie chart for formations
plt.figure(figsize=(8, 8))
plt.pie(
    top_formed_industries['Companies Formed'],
    labels=top_formed_industries['SIC Code'],
    autopct='%1.1f%%',
    startangle=140,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}
)
plt.title('Top 10 Industries by Company Formations')
plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle
plt.show()

# %%
# Pie chart for closures
plt.figure(figsize=(8, 8))
plt.pie(
    df_top_industries_closures['Number of Companies Closed'],
    labels=df_top_industries_closures['SIC Code'],
    autopct='%1.1f%%',
    startangle=140,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}
)
plt.title('Top 10 Industries by Company Closures')
plt.axis('equal')
plt.show()
